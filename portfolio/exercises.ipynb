# %%
#question 1
#asks a user to enter a number
from math import sqrt
number = int(input("Enter a number: "))# input() function is fed to the int() function
if number <= 1:
    print(number, "This is not a prime number")
elif number > 1:
    for i in range(2, int(sqrt(number)) + 1):
        if number % i == 0:
            print(number, "This is not a prime number")
            break
    else:
        print(number, "This is a prime number")
# Out:
# 4 This is not a prime number

# %%
#question 2
count = int(input("How many numers in Fibonacci set to be calculated and displayed?"))
a, b = 0, 1
for i in range(count):
    print(a, end=" ")
    next_num = a + b
    a = b
    b = next_num
# Out:
# 0 1 1 2 3

# %%
#question 3
#  Top half (5 to 1 stars)
n = 5
for i in range(n, 0, -1):
    print("* " * i)
# Bottom half (2 to 5 stars)
for i in range(2,n + 1):
    print("* " * i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
#question 4
def backwards_string():
    user_input = input("Enter a string to be printed out backwards...")
    reversed_string = user_input[::-1]
    print("The string printed out backwards is:", reversed_string)

# %%
backwards_string()
# Out:
# The string printed out backwards is: mees

# %%
#question5 

def min_max(numbers):
    min_value = min(numbers)
    max_value = max(numbers)
    return min_value, max_value

num = [6,8,3,4,7]

min_val, max_val = min_max(num)

print("Min value is:", min_val)
print("Max value is:",max_val)
# Out:
# Min value is: 3
# Max value is: 8

# %%
#question 6 
import random

random_number_guess = random.randint(1, 10) #generate the number between 1 and 10 

guess = 0  #start value before user input 

while guess != random_number_guess:
    guess = int(input("Guess a number between 1 and 10: ")) #asks user to guess the number between 1 and 10 

    if guess > random_number_guess: #check if the guess number is bigger than generated one
        print("Too high! Try again.")
    elif guess < random_number_guess:#check if the guess number is smaller than generated one
        print("Too low! Try again.")
    else:
        print("Congratulations! You guessed the correct number.")
# Out:
# Too low! Try again.
# Too low! Try again.
# Too low! Try again.
# Too low! Try again.
# Too low! Try again.
# Too low! Try again.
# Congratulations! You guessed the correct number.

# %%
#question 7
user_password = "exercise7"
while True:
    password = input("Enter the password: ")
    if password == user_password:
        print("Access Granted!")
        break
    else:
        print("Incorrect password. Try again.")
# Out:
# Incorrect password. Try again.
# Incorrect password. Try again.
# Access Granted!

# %%
#guestion 8 
import math

def series(x, N):
    total = 0
    for i in range(1, N + 1):
        total += (x * (5**i)**2) / (i + math.factorial(i + 1))
    return round(total, 2)


x = int(input("Enter x: "))
N = int(input("Enter N: "))

print("Result:", series(x, N))
# Out:
# Result: 1330.32

# %%
#question 9 
import numpy as np
import matplotlib.pyplot as plt
import PIL  # Python Imaging Library - image editing
import urllib
image_url = "https://thumbs.dreamstime.com/b/ocean-sunset-landscape-bird-high-resolution-image-flying-towards-colorful-romantic-sky-246711534.jpg"

image_data = urllib.request.urlopen(image_url)
image = PIL.Image.open(image_data)
np_image = np.array(image)

horizontal_mirror = np.fliplr(np_image)

# Vertical mirror (top-bottom flip)
vertical_mirror = np.flipud(np_image)

# Display images
plt.figure(figsize=(10,4))

plt.subplot(1,3,1)
plt.title("Original")
plt.imshow(np_image)
plt.axis("off")

plt.subplot(1,3,2)
plt.title("Horizontal Mirror")
plt.imshow(horizontal_mirror)
plt.axis("off")

plt.subplot(1,3,3)
plt.title("Vertical Mirror")
plt.imshow(vertical_mirror)
plt.axis("off")

plt.show()

# %%
#question 10     fix this one 
import numpy as np 
# Temperature data in Celsius
temps = [22, 24, 19, 21, 23, 25, 26, 27, 24, 23, 20, 22, 21, 19, 18, 22, 23,
         24, 26, 28, 30, 27, 25, 26, 24, 22, 21, 20, 19, 23]

# 1) Create a NumPy array from the list
temp_array = np.array(temps)

# 2) Find minimum, maximum, and average temperature
print("Min:", temp_array.min())
print("Max:", temp_array.max())
print("Average:", temp_array.mean())

# 3) Convert Celsius to Fahrenheit: F = (C * 9/5) + 32
fahrenheit_array = (temp_array * 9/5) + 32
print("Temperatures in Fahrenheit:", fahrenheit_array)

# 4) Find all days where temperature was above 25°C
above_25 = temp_array[temp_array > 25]   # filtering using condition
print("Temperatures above 25°C:", above_25)

# 5) Count how many days had temperatures below 20°C
below_20_count = np.sum(temp_array < 20)  # counts True values
print("Number of days below 20°C:", below_20_count)

# 6) Sort the temperature data in ascending order
sorted_temps = np.sort(temp_array)
print("Sorted temperatures:", sorted_temps)

# 7) Reshape the 1D array into a 5x6 2D array (5 weeks, 6 days each)
weeks = temp_array.reshape(5, 6)
print("Temperature data reshaped into 5x6 array:\n", weeks)
# Out:
# Min: 18
# Max: 30
# Average: 23.133333333333333
# Temperatures in Fahrenheit: [71.6 75.2 66.2 69.8 73.4 77.  78.8 80.6 75.2 73.4 68.  71.6 69.8 66.2
#  64.4 71.6 73.4 75.2 78.8 82.4 86.  80.6 77.  78.8 75.2 71.6 69.8 68.
#  66.2 73.4]
# Temperatures above 25°C: [26 27 26 28 30 27 26]
# Number of days below 20°C: 4
# Sorted temperatures: [18 19 19 19 20 20 21 21 21 22 22 22 22 23 23 23 23 24 24 24 24 25 25 26
#  26 26 27 27 28 30]
# Temperature data reshaped into 5x6 array:
#  [[22 24 19 21 23 25]
#  [26 27 24 23 20 22]
#  [21 19 18 22 23 24]
#  [26 28 30 27 25 26]
#  [24 22 21 20 19 23]]

# %%
#question 11
import pandas as pd
import numpy as np

np.random.seed(42)
df = pd.DataFrame(data=np.random.randn(5,4),
                  index=['A', 'B', 'C', 'D', 'E'],
                  columns=['Col1', 'Col2', 'Col3', 'Col4']
                  )

# %%
df #displays the datafarame
# Out:
#        Col1      Col2      Col3      Col4
# A  0.496714 -0.138264  0.647689  1.523030
# B -0.234153 -0.234137  1.579213  0.767435
# C -0.469474  0.542560 -0.463418 -0.465730
# D  0.241962 -1.913280 -1.724918 -0.562288
# E -1.012831  0.314247 -0.908024 -1.412304

# %%
df.shape #displays the shape of the df
# Out:
# (5, 4)

# %%
df.info() #display the summary information
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, A to E
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    5 non-null      float64
#  1   Col2    5 non-null      float64
#  2   Col3    5 non-null      float64
#  3   Col4    5 non-null      float64
# dtypes: float64(4)
# memory usage: 372.0+ bytes

# %%
df.describe()  #display the statictics
# Out:
#            Col1      Col2      Col3      Col4
# count  5.000000  5.000000  5.000000  5.000000
# mean  -0.195556 -0.285775 -0.173892 -0.029971
# std    0.594794  0.964283  1.301617  1.165307
# min   -1.012831 -1.913280 -1.724918 -1.412304
# 25%   -0.469474 -0.234137 -0.908024 -0.562288
# 50%   -0.234153 -0.138264 -0.463418 -0.465730
# 75%    0.241962  0.314247  0.647689  0.767435
# max    0.496714  0.542560  1.579213  1.523030

# %%
#question 12
